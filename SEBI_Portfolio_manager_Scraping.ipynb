# %%
import pandas as pd 
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
from bs4 import BeautifulSoup
import time 
import requests

# %%
URL = "https://www.sebi.gov.in/sebiweb/other/OtherAction.do?doPmr=yes"
driver = webdriver.Chrome()
driver.maximize_window()
driver.get(URL)

# General Information
Name_of_the_Portfolio_Manager = []
Registration_Number = []
Date_of_Registration = []
Registered_Address_of_the_Portfolio_Manager = []
Name_of_Principal_Officer = []
Email_ID_of_the_Principal_Officer = []
Contact_Number_Direct_of_the_Principal_Officer = []
Name_of_Compliance_Officer = []
Email_ID_of_the_Compliance_Officer = []
No_of_clients_as_on_last_day_of_the_month = []
Total_Assets_under_Management_AUM_as_on_last_day_of_the_month_Amount_in_INR_crores = []

# Break Up of Client of the Portfolio Manager
No_of_unique_PF_EPFO = []
No_of_unique_Corporates = []
No_of_unique_Non_Corporates = []
No_of_unique_Non_Residents = []
No_of_unique_FPI = []
No_of_unique_Others = []
No_of_unique_total = []

AUM_PF_EPFO = []
AUM_Corporates = []
AUM_Non_Corporates = []
AUM_Non_Residents = []
AUM_FPI = []
AUM_Others = []
AUM_total = []

#Break-up assets under managment of the Portfolio Manager
Discretionary_Equity_Listed = []
Discretionary_Equity_Unlisted = []
Discretionary_Plain_Debt_Listed = []
Discretionary_Plain_Debt_Unlisted = []
Discretionary_Structured_Debt_Listed = []
Discretionary_Structured_Debt_Unlisted = []
Discretionary_Derivatives_Equity = []
Discretionary_Derivatives_Commodity = []
Discretionary_Derivatives_Others = []
Discretionary_Mutual_Funds = []
Discretionary_Others = []
Discretionary_Total = []

Non_Discretionary_Equity_Listed = []
Non_Discretionary_Equity_Unlisted = []
Non_Discretionary_Plain_Debt_Listed = []
Non_Discretionary_Plain_Debt_Unlisted = []
Non_Discretionary_Structured_Debt_Listed = []
Non_Discretionary_Structured_Debt_Unlisted = [] 
Non_Discretionary_Derivatives_Equity = []
Non_Discretionary_Derivatives_Commodity = []
Non_Discretionary_Derivatives_Others = []
Non_Discretionary_Mutual_Funds = []
Non_Discretionary_Others = []
Non_Discretionary_Total = []
Advisory_Total = []

# Data for Discretioary Services
# A Break up of Clients
A_No_of_unique_PF_EPFO = []
A_No_of_unique_Corporates = []
A_No_of_unique_Non_Corporates = []
A_No_of_unique_Non_Residents = []
A_No_of_unique_FPI = []
A_No_of_unique_Others = []
A_No_of_unique_total = []

A_AUM_PF_EPFO = []
A_AUM_Corporates = []
A_AUM_Non_Corporates = []
A_AUM_Non_Residents = []
A_AUM_FPI = []
A_AUM_Others = []
A_AUM_total = []

# Data for No-Discretioary Services
# F Break up of Clients
F_No_of_unique_PF_EPFO = []
F_No_of_unique_Corporates = []
F_No_of_unique_Non_Corporates = []
F_No_of_unique_Non_Residents = []
F_No_of_unique_FPI = []
F_No_of_unique_Others = []
F_No_of_unique_total = []
F_AUM_PF_EPFO = []
F_AUM_Corporates = []
F_AUM_Non_Corporates = []
F_AUM_Non_Residents = []
F_AUM_FPI = []
F_AUM_Others = []
F_AUM_total = []

# G Break up assets
g_Equity_Listed = []
g_Equity_Unlisted = []
g_Plain_Debt_Listed = []
g_Plain_Debt_Unlisted = []
g_Structured_Debt_Listed = []
g_Structured_Debt_Unlisted = []
g_Derivatives_Equity = []
g_Derivatives_Commodity = []
g_Derivatives_Others = []
g_Mutual_Funds = []
g_Others = []
g_Total = []

# Funds inflow Outflow
h_Inflow_during_the_month = []
h_Outflow_during_the_month = []
h_Net_flow_during_the_month = []
h_Inflow_during_the_FY = []
h_Outflow_during_the_FY = []
h_Net_flow_during_the_FY = []

# K Break up Clients
k_No_of_clients_PF_EPFO = []
k_No_of_clients_Corporates = []
k_No_of_clients_Non_Corporates = []
k_No_of_clients_Non_Residents = []
k_No_of_clients_FPI = []
k_No_of_clients_Others = []
k_No_of_clients_total = []

k_Value_of_the_Assets_PF_EPFO = []
k_Value_of_the_Assets_Corporates = []
k_Value_of_the_Assets_Non_Corporates = []
k_Value_of_the_Assets_Non_Residents = []
k_Value_of_the_Assets_FPI = []
k_Value_of_the_Assets_Others = []
k_Value_of_the_Assets_total = []

# We can Change the Months and Year


for i in range(2,513): #412
    Company = driver.find_element("xpath",f"//div[@class='dd_area portfolio-search']//select//option[{i}]")
    Company.click()
    time.sleep(2)
#                                                         2 = 2024, 3 = 2019, 4 = 2018
#   Year Button                                         Add 1 to Decrease a Year - Here
    Year2024 = driver.find_element("xpath",f"//div[@class='dd_area']//select//option[2]")
    Year2024.click()
    time.sleep(3)
#                                                         7 = June, 8 = July, 6 = May
#   Month Button                                        Add 1 to increase a month   -  Here
    Month_June = driver.find_element("xpath",f"//div[@class='dd_area'][2]//select//option[7]")
    Month_June.click()
    time.sleep(3)

    Search = driver.find_element("xpath","//div[@class='go_area go-area']/a")
    Search.click()
    time.sleep(1)

    try:
        Name_of_the_Portfolio_Manager_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td")
        Name_of_the_Portfolio_Manager.append(Name_of_the_Portfolio_Manager_xpath.text)
    except:
        Name_of_the_Portfolio_Manager.append(0)

    try:
        Registration_Number_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td") 
        Registration_Number.append(Registration_Number_xpath.text)
    except:
        Registration_Number.append(0)

    try:
        Date_of_Registration_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[3]//td")
        Date_of_Registration.append(Date_of_Registration_xpath.text)
    except:
        Date_of_Registration.append(0)

    try:
        Registered_Address_of_the_Portfolio_Manager_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[4]//td")
        Registered_Address_of_the_Portfolio_Manager.append(Registered_Address_of_the_Portfolio_Manager_xpath.text)
    except:
        Registered_Address_of_the_Portfolio_Manager.append(0)

    try:
        Name_of_Principal_Officer_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[5]//td")
        Name_of_Principal_Officer.append(Name_of_Principal_Officer_xpath.text)
    except:
        Name_of_Principal_Officer.append(0)

    try:
        Email_ID_of_the_Principal_Officer_xpath = driver.find_element("xpath", "//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[6]//td")
        Email_ID_of_the_Principal_Officer.append(Email_ID_of_the_Principal_Officer_xpath.text)
    except:
        Email_ID_of_the_Principal_Officer.append(0)

    try:    
        Contact_Number_Direct_of_the_Principal_Officer_xpath = driver.find_element("xpath", "//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[7]//td")
        Contact_Number_Direct_of_the_Principal_Officer.append(Contact_Number_Direct_of_the_Principal_Officer_xpath.text)
    except:
        Contact_Number_Direct_of_the_Principal_Officer.append(0)

    try:
        Name_of_Compliance_Officer_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[8]//td")
        Name_of_Compliance_Officer.append(Name_of_Compliance_Officer_xpath.text)
    except:
        Name_of_Compliance_Officer.append(0)

    try:
        Email_ID_of_the_Compliance_Officer_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[9]//td")
        Email_ID_of_the_Compliance_Officer.append(Email_ID_of_the_Compliance_Officer_xpath.text)
    except:
        Email_ID_of_the_Compliance_Officer.append(0)
        
    try:        
        No_of_clients_as_on_last_day_of_the_month_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[10]//td")
        No_of_clients_as_on_last_day_of_the_month.append(No_of_clients_as_on_last_day_of_the_month_xpath.text)
    except:
        No_of_clients_as_on_last_day_of_the_month.append(0)

    try:    
        Total_Assets_under_Management_AUM_as_on_last_day_of_the_month_Amount_in_INR_crores_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[11]//td")
        Total_Assets_under_Management_AUM_as_on_last_day_of_the_month_Amount_in_INR_crores.append(Total_Assets_under_Management_AUM_as_on_last_day_of_the_month_Amount_in_INR_crores_xpath.text)
    except:
        Total_Assets_under_Management_AUM_as_on_last_day_of_the_month_Amount_in_INR_crores.append(0)

    time.sleep(2)

#-------
    try:
        No_of_unique_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[2]")
        No_of_unique_PF_EPFO.append(No_of_unique_PF_EPFO_xpath.text)
    except:
        No_of_unique_PF_EPFO.append(0)

    try:    
        No_of_unique_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[3]")
        No_of_unique_Corporates.append(No_of_unique_Corporates_xpath.text)
    except:
        No_of_unique_Corporates.append(0)

    try:
        No_of_unique_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[4]")
        No_of_unique_Non_Corporates.append(No_of_unique_Non_Corporates_xpath.text)
    except:
        No_of_unique_Non_Corporates.append(0)

    try:
        No_of_unique_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[5]")
        No_of_unique_Non_Residents.append(No_of_unique_Non_Residents_xpath.text)
    except:
        No_of_unique_Non_Residents.append(0)

    try:
        No_of_unique_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[6]")
        No_of_unique_FPI.append(No_of_unique_FPI_xpath.text)
    except:
        No_of_unique_FPI.append(0)

    try:
        No_of_unique_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[7]")
        No_of_unique_Others.append(No_of_unique_Others_xpath.text)
    except:
        No_of_unique_Others.append(0)

    try:
        No_of_unique_total_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[1]//td[8]")
        No_of_unique_total.append(No_of_unique_total_xpath.text)
    except:
        No_of_unique_total.append(0)

    try:
        AUM_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[2]")
        AUM_PF_EPFO.append(AUM_PF_EPFO_xpath.text)
    except:
        AUM_PF_EPFO.append(0)

    try:
        AUM_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[3]")
        AUM_Corporates.append(AUM_Corporates_xpath.text)
    except:
        AUM_Corporates.append(0)

    try:
        AUM_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[4]")
        AUM_Non_Corporates.append(AUM_Non_Corporates_xpath.text)
    except:
        AUM_Non_Corporates.append(0)

    try:
        AUM_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[5]")
        AUM_Non_Residents.append(AUM_Non_Residents_xpath.text)
    except:
        AUM_Non_Residents.append(0)

    try:
        AUM_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[6]")
        AUM_FPI.append(AUM_FPI_xpath.text)
    except:
        AUM_FPI.append(0)

    try:
        AUM_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[7]")
        AUM_Others.append(AUM_Others_xpath.text)
    except:
        AUM_Others.append(0)

    try:
        AUM_total_xpath = driver.find_element("xpath","//div[@class='portlet purple']//table[@class='table table-striped table-bordered table-hover background statistics-table']//tr[2]//td[8]")
        AUM_total.append(AUM_total_xpath.text)
    except:
        AUM_total.append(0)

    time.sleep(2)

#-------
    try:
        Discretionary_Equity_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[2]")
        Discretionary_Equity_Listed.append(Discretionary_Equity_Listed_xpath.text)
    except:
        Discretionary_Equity_Listed.append(0)

    try:
        Discretionary_Equity_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[3]")
        Discretionary_Equity_Unlisted.append(Discretionary_Equity_Unlisted_xpath.text)
    except:
        Discretionary_Equity_Unlisted.append(0)

    try:
        Discretionary_Plain_Debt_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[4]") 
        Discretionary_Plain_Debt_Listed.append(Discretionary_Plain_Debt_Listed_xpath.text)
    except:
        Discretionary_Plain_Debt_Listed.append(0)

    try:
        Discretionary_Plain_Debt_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[5]")
        Discretionary_Plain_Debt_Unlisted.append(Discretionary_Plain_Debt_Unlisted_xpath.text)
    except:
        Discretionary_Plain_Debt_Unlisted.append(0)

    try:
        Discretionary_Structured_Debt_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[6]")
        Discretionary_Structured_Debt_Listed.append(Discretionary_Structured_Debt_Listed_xpath.text)
    except:
        Discretionary_Structured_Debt_Listed.append(0)

    try:
        Discretionary_Structured_Debt_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[7]")
        Discretionary_Structured_Debt_Unlisted.append(Discretionary_Structured_Debt_Unlisted_xpath.text)
    except:
        Discretionary_Structured_Debt_Unlisted.append(0)

    try:
        Discretionary_Derivatives_Equity_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[8]")
        Discretionary_Derivatives_Equity.append(Discretionary_Derivatives_Equity_xpath.text)
    except:
        Discretionary_Derivatives_Equity.append(0)

    try:
        Discretionary_Derivatives_Commodity_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[9]")
        Discretionary_Derivatives_Commodity.append(Discretionary_Derivatives_Commodity_xpath.text)
    except:
        Discretionary_Derivatives_Commodity.append(0)

    try:
        Discretionary_Derivatives_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[10]")
        Discretionary_Derivatives_Others.append(Discretionary_Derivatives_Others_xpath.text)
    except:
        Discretionary_Derivatives_Others.append(0)

    try:    
        Discretionary_Mutual_Funds_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[11]")
        Discretionary_Mutual_Funds.append(Discretionary_Mutual_Funds_xpath.text)
    except:
        Discretionary_Mutual_Funds.append(0)

    try:
        Discretionary_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[12]")
        Discretionary_Others.append(Discretionary_Others_xpath.text)
    except:
        Discretionary_Others.append(0)

    try:
        Discretionary_Total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr//td[13]")
        Discretionary_Total.append(Discretionary_Total_xpath.text)
    except:
        Discretionary_Total.append(0)

    time.sleep(2)

    try:
        Non_Discretionary_Equity_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[2]")
        Non_Discretionary_Equity_Listed.append(Non_Discretionary_Equity_Listed_xpath.text)
    except:
        Non_Discretionary_Equity_Listed.append(0)

    try:
        Non_Discretionary_Equity_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[3]")
        Non_Discretionary_Equity_Unlisted.append(Non_Discretionary_Equity_Unlisted_xpath.text)
    except:
        Non_Discretionary_Equity_Unlisted.append(0)

    try:
        Non_Discretionary_Plain_Debt_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[4]")
        Non_Discretionary_Plain_Debt_Listed.append(Non_Discretionary_Plain_Debt_Listed_xpath.text)
    except:
        Non_Discretionary_Plain_Debt_Listed.append(0)

    try:
        Non_Discretionary_Plain_Debt_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[5]")
        Non_Discretionary_Plain_Debt_Unlisted.append(Non_Discretionary_Plain_Debt_Unlisted_xpath.text)
    except:
        Non_Discretionary_Plain_Debt_Unlisted.append(0)

    try:
        Non_Discretionary_Structured_Debt_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[6]")
        Non_Discretionary_Structured_Debt_Listed.append(Non_Discretionary_Structured_Debt_Listed_xpath.text)
    except:
        Non_Discretionary_Structured_Debt_Listed.append(0)

    try:
        Non_Discretionary_Structured_Debt_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[7]")
        Non_Discretionary_Structured_Debt_Unlisted.append(Non_Discretionary_Structured_Debt_Unlisted_xpath.text)
    except:
        Non_Discretionary_Structured_Debt_Unlisted.append(0)

    try:
        Non_Discretionary_Derivatives_Equity_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[8]")
        Non_Discretionary_Derivatives_Equity.append(Non_Discretionary_Derivatives_Equity_xpath.text)
    except:
        Non_Discretionary_Derivatives_Equity.append(0)

    try:
        Non_Discretionary_Derivatives_Commodity_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[9]")
        Non_Discretionary_Derivatives_Commodity.append(Non_Discretionary_Derivatives_Commodity_xpath.text)
    except:
        Non_Discretionary_Derivatives_Commodity.append(0)

    try:    
        Non_Discretionary_Derivatives_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[10]")
        Non_Discretionary_Derivatives_Others.append(Non_Discretionary_Derivatives_Others_xpath.text)
    except:
        Non_Discretionary_Derivatives_Others.append(0)

    try:
        Non_Discretionary_Mutual_Funds_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[11]")
        Non_Discretionary_Mutual_Funds.append(Non_Discretionary_Mutual_Funds_xpath.text)
    except:
        Non_Discretionary_Mutual_Funds.append(0)

    try:
        Non_Discretionary_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[12]")
        Non_Discretionary_Others.append(Non_Discretionary_Others_xpath.text)
    except:
        Non_Discretionary_Others.append(0)

    try:
        Non_Discretionary_Total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[13]")
        Non_Discretionary_Total.append(Non_Discretionary_Total_xpath.text)
    except:
        Non_Discretionary_Total.append(0)

    try:
        Advisory_Total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][3]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[4]//td[2]")
        Advisory_Total.append(Advisory_Total_xpath.text)
    except:
        Advisory_Total.append(0)
    
    time.sleep(2)
#-----------

    try:
        A_No_of_unique_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[2]")
        A_No_of_unique_PF_EPFO.append(A_No_of_unique_PF_EPFO_xpath.text)
    except:
        A_No_of_unique_PF_EPFO.append(0)

    try:
        A_No_of_unique_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[3]")
        A_No_of_unique_Corporates.append(A_No_of_unique_Corporates_xpath.text)
    except:
        A_No_of_unique_Corporates.append(0)

    try:
        A_No_of_unique_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[4]")
        A_No_of_unique_Non_Corporates.append(A_No_of_unique_Non_Corporates_xpath.text)
    except:
        A_No_of_unique_Non_Corporates.append(0)

    try:
        A_No_of_unique_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[5]")
        A_No_of_unique_Non_Residents.append(A_No_of_unique_Non_Residents_xpath.text)
    except:
        A_No_of_unique_Non_Residents.append(0)

    try:
        A_No_of_unique_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[6]")
        A_No_of_unique_FPI.append(A_No_of_unique_FPI_xpath.text)
    except:
        A_No_of_unique_FPI.append(0)

    try:
        A_No_of_unique_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[7]")
        A_No_of_unique_Others.append(A_No_of_unique_Others_xpath.text)
    except:
        A_No_of_unique_Others.append(0)

    try:
        A_No_of_unique_total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[1]//td[8]")
        A_No_of_unique_total.append(A_No_of_unique_total_xpath.text)
    except:
        A_No_of_unique_total.append(0)

    try:
        A_AUM_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[2]")
        A_AUM_PF_EPFO.append(A_AUM_PF_EPFO_xpath.text)
    except:
        A_AUM_PF_EPFO.append(0)

    try:
        A_AUM_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[3]")
        A_AUM_Corporates.append(A_AUM_Corporates_xpath.text)
    except:
        A_AUM_Corporates.append(0)

    try:
        A_AUM_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[4]")
        A_AUM_Non_Corporates.append(A_AUM_Non_Corporates_xpath.text)
    except:
        A_AUM_Non_Corporates.append(0)

    try:
        A_AUM_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[5]")
        A_AUM_Non_Residents.append(A_AUM_Non_Residents_xpath.text)
    except:
        A_AUM_Non_Residents.append(0)

    try:
        A_AUM_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[6]")
        A_AUM_FPI.append(A_AUM_FPI_xpath.text)
    except:
        A_AUM_FPI.append(0)

    try:
        A_AUM_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[7]")
        A_AUM_Others.append(A_AUM_Others_xpath.text)
    except:
        A_AUM_Others.append(0)

    try:
        A_AUM_total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][5]//div//table[@class='table table-striped table-bordered table-hover background statistics-table']//tbody//tr[2]//td[8]")
        A_AUM_total.append(A_AUM_total_xpath.text)
    except:
        A_AUM_total.append(0)

    time.sleep(2)

#-------------
    try:
        F_No_of_unique_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[2]")
        F_No_of_unique_PF_EPFO.append(F_No_of_unique_PF_EPFO_xpath.text)
    except:
        F_No_of_unique_PF_EPFO.append(0)

    try:
        F_No_of_unique_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[3]")
        F_No_of_unique_Corporates.append(F_No_of_unique_Corporates_xpath.text)
    except:
        F_No_of_unique_Corporates.append(0)

    try:
        F_No_of_unique_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[4]")
        F_No_of_unique_Non_Corporates.append(F_No_of_unique_Non_Corporates_xpath.text)
    except:
        F_No_of_unique_Non_Corporates.append(0)

    try:
        F_No_of_unique_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[5]")
        F_No_of_unique_Non_Residents.append(F_No_of_unique_Non_Residents_xpath.text)
    except:
        F_No_of_unique_Non_Residents.append(0)

    try:
        F_No_of_unique_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[6]")
        F_No_of_unique_FPI.append(F_No_of_unique_FPI_xpath.text)
    except:
        F_No_of_unique_FPI.append(0)
    
    try:
        F_No_of_unique_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[7]")
        F_No_of_unique_Others.append(F_No_of_unique_Others_xpath.text)
    except:
        F_No_of_unique_Others.append(0)

    try:
        F_No_of_unique_total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr//td[8]")
        F_No_of_unique_total.append(F_No_of_unique_total_xpath.text)
    except:
        F_No_of_unique_total.append(0)
    
    try:
        F_AUM_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[2]")
        F_AUM_PF_EPFO.append(F_AUM_PF_EPFO_xpath.text)
    except:
        F_AUM_PF_EPFO.append(0)

    try:
        F_AUM_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[3]")
        F_AUM_Corporates.append(F_AUM_Corporates_xpath.text)
    except:
        F_AUM_Corporates.append(0)

    try:
        F_AUM_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[4]")
        F_AUM_Non_Corporates.append(F_AUM_Non_Corporates_xpath.text)
    except:
        F_AUM_Non_Corporates.append(0)

    try:
        F_AUM_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[5]")
        F_AUM_Non_Residents.append(F_AUM_Non_Residents_xpath.text)
    except:
        F_AUM_Non_Residents.append(0)

    try:
        F_AUM_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[6]")
        F_AUM_FPI.append(F_AUM_FPI_xpath.text)
    except:
        F_AUM_FPI.append(0)

    try:
        F_AUM_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[7]")
        F_AUM_Others.append(F_AUM_Others_xpath.text)
    except:
        F_AUM_Others.append(0)

    try:
        F_AUM_total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][11]//table//tbody//tr[2]//td[8]")
        F_AUM_total.append(F_AUM_total_xpath.text)
    except:
        F_AUM_total.append(0)

    time.sleep(2)

#-------------

    try:
        g_Equity_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[1]")
        g_Equity_Listed.append(g_Equity_Listed_xpath.text)
    except:
        g_Equity_Listed.append(0)
        
    try:
        g_Equity_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[2]")
        g_Equity_Unlisted.append(g_Equity_Unlisted_xpath.text)
    except:
        g_Equity_Unlisted.append(0)

    try:
        g_Plain_Debt_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[3]")
        g_Plain_Debt_Listed.append(g_Plain_Debt_Listed_xpath.text)
    except:
        g_Plain_Debt_Listed.append(0)

    try:
        g_Plain_Debt_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[4]")
        g_Plain_Debt_Unlisted.append(g_Plain_Debt_Unlisted_xpath.text)
    except:
        g_Plain_Debt_Unlisted.append(0)

    try:
        g_Structured_Debt_Listed_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[5]")
        g_Structured_Debt_Listed.append(g_Structured_Debt_Listed_xpath.text)
    except:
        g_Structured_Debt_Listed.append(0)

    try:
        g_Structured_Debt_Unlisted_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[6]")
        g_Structured_Debt_Unlisted.append(g_Structured_Debt_Unlisted_xpath.text)
    except:
        g_Structured_Debt_Unlisted.append(0)

    try:
        g_Derivatives_Equity_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[7]")
        g_Derivatives_Equity.append(g_Derivatives_Equity_xpath.text)
    except:
        g_Derivatives_Equity.append(0)

    try:
        g_Derivatives_Commodity_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[8]")
        g_Derivatives_Commodity.append(g_Derivatives_Commodity_xpath.text)
    except:
        g_Derivatives_Commodity.append(0)

    try:
        g_Derivatives_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[9]")
        g_Derivatives_Others.append(g_Derivatives_Others_xpath.text)
    except:
        g_Derivatives_Others.append(0)

    try:
        g_Mutual_Funds_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[10]")
        g_Mutual_Funds.append(g_Mutual_Funds_xpath.text)
    except:
        g_Mutual_Funds.append(0)

    try:
        g_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[11]")
        g_Others.append(g_Others_xpath.text)
    except:
        g_Others.append(0)

    try:
        g_Total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][12]//tbody//tr//th[12]")
        g_Total.append(g_Total_xpath.text)
    except:
        g_Total.append(0)

    time.sleep(2)

#---------------

    try:
        h_Inflow_during_the_month_xpath = driver.find_element("xpath","//div[@class='portlet purple'][13]//tbody//tr[2]//td[1]")
        h_Inflow_during_the_month.append(h_Inflow_during_the_month_xpath.text)
    except:
        h_Inflow_during_the_month.append(0)

    try:
        h_Outflow_during_the_month_xpath = driver.find_element("xpath","//div[@class='portlet purple'][13]//tbody//tr[2]//td[2]")
        h_Outflow_during_the_month.append(h_Outflow_during_the_month_xpath.text)
    except:
        h_Outflow_during_the_month.append(0)

    try:
        h_Net_flow_during_the_month_xpath = driver.find_element("xpath","//div[@class='portlet purple'][13]//tbody//tr[2]//td[3]")
        h_Net_flow_during_the_month.append(h_Net_flow_during_the_month_xpath.text)
    except:
        h_Net_flow_during_the_month.append(0)

    try:
        h_Inflow_during_the_FY_xpath = driver.find_element("xpath","//div[@class='portlet purple'][13]//tbody//tr[2]//td[4]")
        h_Inflow_during_the_FY.append(h_Inflow_during_the_FY_xpath.text)
    except:
        h_Inflow_during_the_FY.append(0)

    try:
        h_Outflow_during_the_FY_xpath = driver.find_element("xpath","//div[@class='portlet purple'][13]//tbody//tr[2]//td[5]")
        h_Outflow_during_the_FY.append(h_Outflow_during_the_FY_xpath.text)
    except:
        h_Outflow_during_the_FY.append(0)

    try:
        h_Net_flow_during_the_FY_xpath = driver.find_element("xpath","//div[@class='portlet purple'][13]//tbody//tr[2]//td[6]")
        h_Net_flow_during_the_FY.append(h_Net_flow_during_the_FY_xpath.text)
    except:
        h_Net_flow_during_the_FY.append(0)
#----------------

    try:
        k_No_of_clients_PF_EPFO_xpath = driver.find_element("xpath", "//div[@class='portlet purple'][16]//tbody//tr[1]//td[2]")
        k_No_of_clients_PF_EPFO.append(k_No_of_clients_PF_EPFO_xpath.text)
    except:
        k_No_of_clients_PF_EPFO.append(0)

    try:
        k_No_of_clients_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[1]//td[3]")
        k_No_of_clients_Corporates.append(k_No_of_clients_Corporates_xpath.text)
    except:
        k_No_of_clients_Corporates.append(0)

    try:
        k_No_of_clients_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[1]//td[4]")
        k_No_of_clients_Non_Corporates.append(k_No_of_clients_Non_Corporates_xpath.text)
    except:
        k_No_of_clients_Non_Corporates.append(0)

    try:
        k_No_of_clients_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[1]//td[5]")
        k_No_of_clients_Non_Residents.append(k_No_of_clients_Non_Residents_xpath.text)
    except:
        k_No_of_clients_Non_Residents.append(0)

    try:
        k_No_of_clients_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[1]//td[6]")
        k_No_of_clients_FPI.append(k_No_of_clients_FPI_xpath.text)
    except:
        k_No_of_clients_FPI.append(0)

    try:
        k_No_of_clients_Others_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[1]//td[7]")
        k_No_of_clients_Others.append(k_No_of_clients_Others_xpath.text)
    except:
        k_No_of_clients_Others.append(0)

    try:
        k_No_of_clients_total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[1]//td[8]")
        k_No_of_clients_total.append(k_No_of_clients_total_xpath.text)
    except:
        k_No_of_clients_total.append(0)

    try:
        k_Value_of_the_Assets_PF_EPFO_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[2]//td[2]")
        k_Value_of_the_Assets_PF_EPFO.append(k_Value_of_the_Assets_PF_EPFO_xpath.text)
    except:
        k_Value_of_the_Assets_PF_EPFO.append(0)

    try:
        k_Value_of_the_Assets_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[2]//td[3]")
        k_Value_of_the_Assets_Corporates.append(k_Value_of_the_Assets_Corporates_xpath.text)
    except:
        k_Value_of_the_Assets_Corporates.append(0)

    try:
        k_Value_of_the_Assets_Non_Corporates_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[2]//td[4]")
        k_Value_of_the_Assets_Non_Corporates.append(k_Value_of_the_Assets_Non_Corporates_xpath.text)
    except:
        k_Value_of_the_Assets_Non_Corporates.append(0)

    try:
        k_Value_of_the_Assets_Non_Residents_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[2]//td[5]")
        k_Value_of_the_Assets_Non_Residents.append(k_Value_of_the_Assets_Non_Residents_xpath.text)
    except:
        k_Value_of_the_Assets_Non_Residents.append(0)

    try:
        k_Value_of_the_Assets_FPI_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[2]//td[6]")
        k_Value_of_the_Assets_FPI.append(k_Value_of_the_Assets_FPI_xpath.text)
    except:
        k_Value_of_the_Assets_FPI.append(0)

    try:
        k_Value_of_the_Assets_Others_xpath = driver.find_element("xpath", "//div[@class='portlet purple'][16]//tbody//tr[2]//td[7]")
        k_Value_of_the_Assets_Others.append(k_Value_of_the_Assets_Others_xpath.text)
    except:
        k_Value_of_the_Assets_Others.append(0)

    try:
        k_Value_of_the_Assets_total_xpath = driver.find_element("xpath","//div[@class='portlet purple'][16]//tbody//tr[2]//td[8]")
        k_Value_of_the_Assets_total.append(k_Value_of_the_Assets_total_xpath.text)
    except:
        k_Value_of_the_Assets_total.append(0)
        

time.sleep(2)
driver.close()

# %%
June2024 = {
    "Name of the Portfolio Manager" : Name_of_the_Portfolio_Manager,
    "Registration Number" : Registration_Number,
    "Date of Registration" : Date_of_Registration,
    "Registered Address of the Portfolio Manager" : Registered_Address_of_the_Portfolio_Manager,
    "Name of Principal Officer" : Name_of_Principal_Officer,
    "Email ID of the Principal Officer" : Email_ID_of_the_Principal_Officer,
    "Contact Number (Direct) of the Principal Officer" : Contact_Number_Direct_of_the_Principal_Officer,
    "Name of Compliance Officer" : Name_of_Compliance_Officer,
    "Email ID of the Compliance Officer" : Email_ID_of_the_Compliance_Officer,
    "No. of clients as on last day of the month" : No_of_clients_as_on_last_day_of_the_month,
    "Total Assets under Management (AUM) as on last day of the month (Amount in INR crores)": Total_Assets_under_Management_AUM_as_on_last_day_of_the_month_Amount_in_INR_crores,
    "No_of_unique_PF/EPFO" : No_of_unique_PF_EPFO,
    "No_of_unique_Corporates" : No_of_unique_Corporates,
    "No_of_unique_Non-Corporates" : No_of_unique_Non_Corporates,
    "No_of_unique_Non-Residents" : No_of_unique_Non_Residents,
    "No_of_unique_FPI" : No_of_unique_FPI,
    "No_of_unique_Others" : No_of_unique_Others,
    "No_of_unique_total" : No_of_unique_total,
    "AUM_PF/EPFO" : AUM_PF_EPFO,
    "AUM_Corporates" : AUM_Corporates,
    "AUM_Non-Corporates" : AUM_Non_Corporates,
    "AUM_Non-Residents" : AUM_Non_Residents,
    "AUM_FPI" : AUM_FPI,
    "AUM_Others" : AUM_Others,
    "AUM_total" : AUM_total,
    "Discretionary_Equity Listed" : Discretionary_Equity_Listed,
    "Discretionary_Equity Unlisted" : Discretionary_Equity_Unlisted,
    "Discretionary_Plain Debt Listed" : Discretionary_Plain_Debt_Listed,
    "Discretionary_Plain Debt Unlisted" : Discretionary_Plain_Debt_Unlisted,
    "Discretionary_Structured Debt Listed" : Discretionary_Structured_Debt_Listed,
    "Discretionary_Structured Debt Unlisted" : Discretionary_Structured_Debt_Unlisted,
    "Discretionary_Derivatives Equity" : Discretionary_Derivatives_Equity,
    "Discretionary_Derivatives Commodity" : Discretionary_Derivatives_Commodity,
    "Discretionary_Derivatives Others" : Discretionary_Derivatives_Others,
    "Discretionary_Mutual Funds" : Discretionary_Mutual_Funds,
    "Discretionary_Others" : Discretionary_Others,
    "Discretionary_Total" : Discretionary_Total,
    "Non-Discretionary_Equity Listed" : Non_Discretionary_Equity_Listed,
    "Non-Discretionary_Equity Unlisted" : Non_Discretionary_Equity_Unlisted,
    "Non-Discretionary_Plain Debt Listed" : Non_Discretionary_Plain_Debt_Listed,
    "Non-Discretionary_Plain Debt Unlisted" : Non_Discretionary_Plain_Debt_Unlisted,
    "Non-Discretionary_Structured Debt Listed" : Non_Discretionary_Structured_Debt_Listed,
    "Non-Discretionary_Structured Debt Unlisted" : Non_Discretionary_Structured_Debt_Unlisted,
    "Non-Discretionary_Derivatives Equity" : Non_Discretionary_Derivatives_Equity,
    "Non-Discretionary_Derivatives Commodity" : Non_Discretionary_Derivatives_Commodity,
    "Non-Discretionary_Derivatives Others" : Non_Discretionary_Derivatives_Others,
    "Non-Discretionary_Mutual Funds" : Non_Discretionary_Mutual_Funds,
    "Non-Discretionary_Others" : Non_Discretionary_Others,
    "Non-Discretionary_Total" : Non_Discretionary_Total,
    "Advisory_Total" : Advisory_Total,
    "A_No_of_unique_PF/EPFO": A_No_of_unique_PF_EPFO,
    "A_No_of_unique_Corporates" : A_No_of_unique_Corporates,
    "A_No_of_unique_Non-Corporates" : A_No_of_unique_Non_Corporates,
    "A_No_of_unique_Non-Residents" : A_No_of_unique_Non_Residents,
    "A_No_of_unique_FPI" : A_No_of_unique_FPI,
    "A_No_of_unique_Others" : A_No_of_unique_Others,
    "A_No_of_unique_total" : A_No_of_unique_total,
    "A_AUM_PF/EPFO" : A_AUM_PF_EPFO,
    "A_AUM_Corporates" : A_AUM_Corporates,
    "A_AUM_Non-Corporates" : A_AUM_Non_Corporates,
    "A_AUM_Non-Residents" : A_AUM_Non_Residents,
    "A_AUM_FPI" : A_AUM_FPI,
    "A_AUM_Others" : A_AUM_Others,
    "A_AUM_total" : A_AUM_total,
    "F_No_of_unique_PF/EPFO" : F_No_of_unique_PF_EPFO,
    "F_No_of_unique_Corporates" : F_No_of_unique_Corporates,
    "F_No_of_unique_Non-Corporates" : F_No_of_unique_Non_Corporates,
    "F_No_of_unique_Non-Residents" : F_No_of_unique_Non_Residents,
    "F_No_of_unique_FPI" : F_No_of_unique_FPI,
    "F_No_of_unique_Others" : F_No_of_unique_Others,
    "F_No_of_unique_total" : F_No_of_unique_total,
    "F_AUM_PF/EPFO" : F_AUM_PF_EPFO,
    "F_AUM_Corporates" : F_AUM_Corporates,
    "F_AUM_Non-Corporates" : F_AUM_Non_Corporates,
    "F_AUM_Non-Residents" : F_AUM_Non_Residents,
    "F_AUM_FPI" : F_AUM_FPI,
    "F_AUM_Others" : F_AUM_Others,
    "F_AUM_total": F_AUM_total,
    "g_Equity Listed" : g_Equity_Listed,
    "g_Equity Unlisted" : g_Equity_Unlisted,
    "g_Plain Debt Listed" : g_Plain_Debt_Listed,
    "g_Plain Debt Unlisted" : g_Plain_Debt_Unlisted,
    "g_Structured Debt Listed" : g_Structured_Debt_Listed,
    "g_Structured Debt Unlisted" : g_Structured_Debt_Unlisted,
    "g_Derivatives Equity" : g_Derivatives_Equity,
    "g_Derivatives Commodity" : g_Derivatives_Commodity,
    "g_Derivatives Others" : g_Derivatives_Others,
    "g_Mutual Funds" : g_Mutual_Funds,
    "g_Others" : g_Others,
    "g_Total" : g_Total,
    "h_Inflow_during_the_month" : h_Inflow_during_the_month,
    "h_Outflow_during_the_month" : h_Outflow_during_the_month,
    "h_Net_flow_during_the_month" : h_Net_flow_during_the_month,
    "h_Inflow_during_the_FY" : h_Inflow_during_the_FY,
    "h_Outflow_during_the_FY" : h_Outflow_during_the_FY,
    "h_Net_flow_during_the_FY" : h_Net_flow_during_the_FY,
    "k_No_of_clients_PF/EPFO" : k_No_of_clients_PF_EPFO,
    "k_No_of_clients_Corporates" : k_No_of_clients_Corporates,
    "k_No_of_clients_Non-Corporates" : k_No_of_clients_Non_Corporates,
    "k_No_of_clients_Non-Residents" : k_No_of_clients_Non_Residents,
    "k_No_of_clients_FPI" : k_No_of_clients_FPI,
    "k_No_of_clients_Others" : k_No_of_clients_Others,
    "k_No_of_clients_total" : k_No_of_clients_total,
    "k_Value_of_the_Assets_PF/EPFO" :  k_Value_of_the_Assets_PF_EPFO,
    "k_Value_of_the_Assets_Corporates" : k_Value_of_the_Assets_Corporates,
    "k_Value_of_the_Assets_Non-Corporates" : k_Value_of_the_Assets_Non_Corporates,
    "k_Value_of_the_Assets_Non-Residents" : k_Value_of_the_Assets_Non_Residents,
    "k_Value_of_the_Assets_FPI" : k_Value_of_the_Assets_FPI,
    "k_Value_of_the_Assets_Others" : k_Value_of_the_Assets_Others,
    "k_Value_of_the_Assets_total" : k_Value_of_the_Assets_total

}

# %%
June2024 = pd.DataFrame(June2024)

# %%
June2024.to_excel("D:/DA/assigments/June2024.xlsx")

# %%
June2024
# Out:
#                    Name of the Portfolio Manager Registration Number  \
# 0                              1729 Advisors LLP        INP000008464
# 1                   2POINT2 CAPITAL ADVISORS LLP        INP000005190
# 2    360 ONE Alternates Asset Management Limited        INP000008640
# 3               360 ONE Asset Management Limited        INP000004565
# 4             360 ONE PORTFOLIO MANAGERS LIMITED        INP000005874
# ..                                           ...                 ...
# 506                                            0                   0
# 507                            Xponent Tribe LLP        INP000008516
# 508               XPONENTIA CAPITAL PARTNERS LLP        INP000007483
# 509       ZEN WEALTH MANAGEMENT SERVICES LIMITED        INP000000936
# 510                  Zeva Capsol Private Limited        INP000007872
#
#     Date of Registration        Registered Address of the Portfolio Manager  \
# ...
